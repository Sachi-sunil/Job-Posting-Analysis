# %% [markdown]
# Analyse Linkedin Job Posting Dataset

# %%
import pandas as pd

df = pd.read_csv("Datasets/LinkedinDataset.csv")

# %%
df.head()
# Out:
#                                   Co_Nm  Co_Pg_Lstd  Emp_Cnt  Flw_Cnt  \
# 0                           HearingLife        True     1171    11417
# 1          Metalcraft of Mayville, Inc.        True      300     2923
# 2  U.S. Tsubaki Power Transmission, LLC        True      314     8487
# 3      Episcopal Communities & Services        True       36      305
# 4                            iHerb, LLC        True     1227    51933
#
#                                              Job_Ttl  \
# 0                              Hearing Care Provider
# 1  Shipping & Receiving Associate 2nd shift (Beav...
# 2                               Manager, Engineering
# 3                                               Cook
# 4        Principal Cloud Security Architect (Remote)
#
#                                             Job_Desc  Is_Supvsr    max_sal  \
# 0  Overview\n\nHearingLife is a national hearing ...      False    5250.00
# ...

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Co_Nm            33242 non-null  object
#  1   Co_Pg_Lstd       33246 non-null  bool
#  2   Emp_Cnt          33246 non-null  int64
#  3   Flw_Cnt          33246 non-null  int64
#  4   Job_Ttl          33246 non-null  object
#  5   Job_Desc         33244 non-null  object
#  6   Is_Supvsr        33246 non-null  bool
#  7   max_sal          33246 non-null  float64
#  8   med_sal          33246 non-null  float64
#  9   min_sal          33246 non-null  float64
#  10  py_prd           33246 non-null  object
#  11  py_lstd          33246 non-null  bool
#  12  wrk_typ          33246 non-null  object
#  13  loc              33246 non-null  object
#  14  st_code          33246 non-null  object
#  15  is_remote        33246 non-null  int64
#  16  views            33246 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Co_Nm                  4
# Co_Pg_Lstd             0
# Emp_Cnt                0
# Flw_Cnt                0
# Job_Ttl                0
# Job_Desc               2
# Is_Supvsr              0
# max_sal                0
# med_sal                0
# min_sal                0
# py_prd                 0
# py_lstd                0
# wrk_typ                0
# loc                    0
# st_code                0
# is_remote              0
# views                  0
# app_typ                0
# app_is_off             0
# xp_lvl                 0
# domain             13558
# has_post_domain        0
# is_sponsored           0
# base_comp              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(118)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#              Emp_Cnt       Flw_Cnt       max_sal       med_sal        min_sal  \
# count   33128.000000  3.312800e+04  3.312800e+04  3.312800e+04   33128.000000
# mean    15502.514851  5.248491e+05  3.192240e+04  2.754909e+04   23175.791204
# std     62285.700537  2.713417e+06  6.831512e+04  5.797332e+04   49035.974999
# min         0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%       147.000000  8.133000e+03  0.000000e+00  0.000000e+00       0.000000
# 50%      1229.000000  3.786050e+04  0.000000e+00  0.000000e+00       0.000000
# 75%      8129.000000  1.680360e+05  1.000000e+02  9.250000e+01      85.000000
# max    829111.000000  3.188720e+07  1.300000e+06  1.050000e+06  998426.000000
#
#           is_remote         views  is_sponsored     base_comp
# count  33128.000000  33128.000000  33128.000000  33128.000000
# mean       0.144893     45.583736      0.244627      0.401805
# std        0.351998    127.170535      0.429872      0.490270
# ...

# %%
df['Job_Ttl'].value_counts().head(10)
# Out:
# Job_Ttl
# Sales Director [Owner/Operator]    120
# Sales Manager                       99
# Project Manager                     98
# Customer Service Representative     85
# Senior Accountant                   83
# Retail Sales Associate              83
# Staff Accountant                    80
# Sales Director {Owner/Operator}     78
# Administrative Assistant            77
# Sales Associate                     77
# Name: count, dtype: int64

# %%
df['Co_Nm'].value_counts().head(10)
# Out:
# Co_Nm
# No Company Page            701
# Insight Global             217
# City Lifestyle             198
# CareerStaff Unlimited      186
# Aya Healthcare             172
# Verizon                    154
# Vivian Health              143
# Jobot                      125
# Fusion Medical Staffing    124
# Cogent Communications      108
# Name: count, dtype: int64

# %%
df['wrk_typ'].value_counts()
# Out:
# wrk_typ
# Full-time     26814
# Contract       3458
# Part-time      2216
# Temporary       260
# Internship      225
# Other           110
# Volunteer        45
# Name: count, dtype: int64

# %%
df.groupby('Job_Ttl')['med_sal'].mean().sort_values(ascending=False).head(10)
# Out:
# Job_Ttl
# Quantitative Developer                                               1050000.0
# Criminal Court Clerk                                                  998426.0
# Tech Lead Manager (L6-L8) | Disruptive FinTech                        875000.0
# Fintech Startup | Tech Lead Manager - Software Engineer               800000.0
# Head of Sales & Marketing (Healthcare)                                800000.0
# Distinguished Engineer, Trilogy (Remote) - $800,000/year USD          800000.0
# Chief Software Architect, Trilogy (Remote) - $800,000/year USD        800000.0
# Registered Nurse or Licensed Practical Nurse - RN or LPN - School     785358.0
# Director of Product, MyBSWHealth                                      750000.0
# Urologist                                                             700000.0
# Name: med_sal, dtype: float64

# %%
df['loc'].value_counts().tail(10)
# Out:
# loc
# Yanceyville, NC      1
# Fowler, CA           1
# Methuen, MA          1
# Lakeway, TX          1
# Fort Stockton, TX    1
# Ennis, TX            1
# Dresden, TN          1
# Brunswick, TN        1
# South Boston, VA     1
# Gainesville, MS      1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_jobs = df['Job_Ttl'].value_counts().head(10)
sns.barplot(y=top_jobs.index, x=top_jobs.values)
plt.title("Top 10 Job Titles")
plt.xlabel("Number of Postings")
plt.ylabel("Job Title")
plt.show()


sns.countplot(x='is_remote', data=df)
plt.title("Remote vs On-site Jobs")
plt.xticks([0, 1], ['On-site', 'Remote'])
plt.show()

# %%
df.drop(columns=['Co_Pg_Lstd', 'py_lstd', 'app_is_off'], inplace=True)

# %%
top_titles = df['Job_Ttl'].value_counts().head(10)
sns.barplot(y=top_titles.index, x=top_titles.values, palette="coolwarm")
plt.title("Top 10 Job Titles")
plt.xlabel("Number of Postings")
plt.ylabel("Job Titles")
plt.show()
# Out:
# C:\Users\SACHIN\AppData\Local\Temp\ipykernel_8200\1997693879.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_titles.index, x=top_titles.values, palette="coolwarm")

# %%
top_companies = df['Co_Nm'].value_counts().head(10)
sns.barplot(y=top_companies.index, x=top_companies.values, palette="magma")
plt.title("Top Hiring Companies")
plt.xlabel("Number of Postings")
plt.ylabel("Company")
plt.show()
# Out:
# C:\Users\SACHIN\AppData\Local\Temp\ipykernel_8200\1664470758.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_companies.index, x=top_companies.values, palette="magma")

# %%
remote_jobs = df['is_remote'].value_counts()
sns.barplot(x=remote_jobs.index, y=remote_jobs.values)
plt.title("Remote vs On-site Jobs")
plt.xticks([0, 1], ['On-site', 'Remote'])
plt.ylabel("Count")
plt.show()

# %%
top_salary_jobs = df.groupby('Job_Ttl')['med_sal'].mean().sort_values(ascending=False).head(10)
top_salary_jobs.plot(kind='barh', color='green')
plt.title("Top 10 Job Titles by Median Salary")
plt.xlabel("Median Salary")
plt.ylabel("Job Title")
plt.show()

# %%
# Work Type
df['wrk_typ'].value_counts().plot(kind='bar', color='skyblue', title='Work Type Distribution')
plt.ylabel("Number of Postings")
plt.show()

# Experience Level
df['xp_lvl'].value_counts().plot(kind='bar', color='orange', title='Experience Level Distribution')
plt.ylabel("Number of Postings")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['med_sal'], bins=30, kde=True, color='teal')
plt.title('Distribution of Median Salary')
plt.xlabel('Median Salary')
plt.ylabel('Number of Job Postings')
plt.show()

# %%
remote_salary = df.groupby('is_remote')['med_sal'].mean()
remote_salary.index = ['On-site', 'Remote']

remote_salary.plot(kind='bar', color=['#FF9999','#66B3FF'])
plt.title('Average Median Salary: Remote vs On-site')
plt.ylabel('Average Median Salary')
plt.xticks(rotation=0)
plt.show()

# %%
xp_salary = df.groupby('xp_lvl')['med_sal'].mean().sort_values()
xp_salary.plot(kind='barh', color='slateblue')
plt.title('Median Salary by Experience Level')
plt.xlabel('Median Salary')
plt.ylabel('Experience Level')
plt.show()

# %%
top_locations = df['loc'].value_counts().head(10)
sns.barplot(y=top_locations.index, x=top_locations.values, palette='viridis')
plt.title("Top 10 Job Locations")
plt.xlabel("Number of Postings")
plt.ylabel("Location")
plt.show()
# Out:
# C:\Users\SACHIN\AppData\Local\Temp\ipykernel_8200\2734632248.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_locations.index, x=top_locations.values, palette='viridis')

# %%
sns.scatterplot(data=df, x='views', y='base_comp', alpha=0.5)
plt.title('Views vs Compensation')
plt.xlabel('Views')
plt.ylabel('Base Compensation')
plt.show()

# %%
df.to_csv("cleaned_job_dataset.csv", index=False)
